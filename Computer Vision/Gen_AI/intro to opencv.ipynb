# %% [markdown]
# # INTRODUCE TO OPENCV  & IMAGE PROCESSING
#
# - https://opencv.org/
# - pip install opencv-python (python installation)

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2

# %%
img =  cv2.imread(r'C:\Users\pc\Downloads\17th - Color detection, Ocr Model\17th - Color detection, Ocr Model\Gen Ai through computre vision\lover.jpg')

#imread never gives you error even though you mention any image

# %%
type(img) # as we define incorret  image thats why type is none type
# Out:
# numpy.ndarray

# %%
img =  cv2.imread(r'C:\Users\pc\Downloads\17th - Color detection, Ocr Model\17th - Color detection, Ocr Model\Gen Ai through computre vision\lover.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (401, 401, 3)

# %%
plt.imshow(img)

# if you notice below image actual image is different then imshow image because opencv read the image as BGR

# %%
img
# Out:
# array([[[ 54,  58,  46],
#         [ 54,  58,  46],
#         [ 54,  58,  46],
#         ...,
#         [112, 113,  79],
#         [ 98,  99,  67],
#         [ 96,  94,  64]],
#
#        [[ 54,  58,  46],
#         [ 54,  58,  46],
#         [ 54,  58,  46],
#         ...,
#         [116, 120,  85],
#         [105, 106,  72],
#         [ 98,  96,  66]],
#
#        [[ 56,  60,  48],
#         [ 56,  60,  48],
#         [ 56,  60,  48],
#         ...,
#         [127, 131,  95],
#         [115, 116,  82],
#         [104, 102,  72]],
#
#        ...,
#
#        [[127, 162, 202],
#         [134, 170, 208],
#         [136, 169, 208],
#         ...,
#         [147, 166, 157],
#         [134, 153, 144],
#         [120, 141, 133]],
#
#        [[129, 161, 202],
#         [135, 168, 207],
#         [138, 170, 206],
#         ...,
#         [146, 165, 156],
#         [133, 152, 143],
#         [119, 140, 132]],
#
#        [[132, 163, 202],
#         [136, 168, 204],
#         [137, 169, 205],
#         ...,
#         [142, 163, 154],
#         [129, 150, 142],
#         [118, 138, 133]]], dtype=uint8)

# %% [markdown]
# - matplotlibe channel--> Always give the channel ( R G B) || red, green, blue
# - opencv channel --> (B G R) || blue , green , red

# %%
fix_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(fix_img)

# %%
img_gray = cv2.imread(r'C:\Users\pc\Downloads\17th - Color detection, Ocr Model\17th - Color detection, Ocr Model\Gen Ai through computre vision\lover.jpg',cv2.IMREAD_GRAYSCALE)

# %%
img_gray.shape # it dont have 3 channel now
# Out:
# (401, 401)

# %%
img_gray
# Out:
# array([[ 54,  54,  54, ..., 103,  89,  85],
#        [ 54,  54,  54, ..., 109,  96,  87],
#        [ 56,  56,  56, ..., 120, 106,  93],
#        ...,
#        [170, 177, 177, ..., 161, 148, 136],
#        [170, 176, 177, ..., 160, 147, 135],
#        [171, 175, 176, ..., 158, 145, 134]], dtype=uint8)

# %%
img_gray.min()
# Out:
# np.uint8(5)

# %%
img_gray.max()
# Out:
# np.uint8(254)

# %%
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap = 'magma') # try with green

# %%
#plt.imshow(img_gray, cmap = 'green')
plt.imshow(img_gray, cmap = 'Accent')

# %%
plt.imshow(img)

# %%
plt.imshow(fix_img)

# %%
fix_img.shape
# Out:
# (401, 401, 3)

# %%
fix_img_1 = cv2.resize(fix_img,(600,500)) # 600 -width & 500- height

# %%
plt.imshow(fix_img_1)

# %%
fix_img.shape
# Out:
# (401, 401, 3)

# %%
w_ratio = 0.3
h_ratio = 0.3

# %%
fix_img_2 = cv2.resize(fix_img,(0,0), fix_img, w_ratio, h_ratio)

# %%
fix_img_2.shape # 50% of the fix_img shape
# Out:
# (120, 120, 3)

# %%
plt.imshow(fix_img_2)

# %%
plt.imshow(fix_img)

# %%
img3 = cv2.flip(fix_img_2,0)
plt.imshow(img3)

# %%
cv2.imwrite('new generate image.jpg',img3)
# Out:
# True
