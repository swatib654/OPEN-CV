# %% [markdown]
# # INTRODUCE TO OPENCV  & IMAGE PROCESSING
#
# - https://opencv.org/
# - pip install opencv-python (python installation)

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2

# %%
img =  cv2.imread(r'C:\Users\pc\Downloads\17th - Color detection, Ocr Model\17th - Color detection, Ocr Model\Gen Ai through computre vision\download.jpeg')

#imread never gives you error even though you mention any image

# %%
type(img) # as we define incorret  image thats why type is none type
# Out:
# numpy.ndarray

# %%
img =  cv2.imread(r'C:\Users\pc\Downloads\17th - Color detection, Ocr Model\17th - Color detection, Ocr Model\Gen Ai through computre vision\new generate image.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (300, 220, 3)

# %%
plt.imshow(img)

# if you notice below image actual image is different then imshow image because opencv read the image as BGR

# %%
img
# Out:
# array([[[ 87,  75,  51],
#         [ 70,  59,  32],
#         [ 69,  55,  27],
#         ...,
#         [129, 133,  74],
#         [120, 123,  68],
#         [104, 107,  52]],
#
#        [[ 59,  47,  23],
#         [ 94,  83,  56],
#         [ 99,  88,  58],
#         ...,
#         [171, 174, 118],
#         [148, 151,  95],
#         [132, 135,  79]],
#
#        [[ 91,  82,  55],
#         [106,  98,  68],
#         [117, 111,  76],
#         ...,
#         [125, 126,  70],
#         [108, 109,  53],
#         [116, 118,  59]],
#
#        ...,
#
#        [[ 26,  46,   0],
#         [ 24,  44,   0],
#         [ 20,  40,   0],
#         ...,
#         [ 66,  94,  18],
#         [104, 134,  45],
#         [ 74, 106,  11]],
#
#        [[ 27,  47,   2],
#         [ 23,  42,   0],
#         [ 21,  40,   1],
#         ...,
#         [ 83, 114,  29],
#         [107, 137,  48],
#         [ 84, 115,  22]],
#
#        [[ 33,  53,   8],
#         [ 24,  42,   1],
#         [ 24,  41,   7],
#         ...,
#         [ 77, 109,  20],
#         [ 65,  95,   6],
#         [ 57,  88,   0]]], dtype=uint8)

# %% [markdown]
# - matplotlibe channel--> Always give the channel ( R G B) || red, green, blue
# - opencv channel --> (B G R) || blue , green , red

# %%
fix_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(fix_img)

# %%
img_gray = cv2.imread(r'C:\Users\pc\Downloads\17th - Color detection, Ocr Model\17th - Color detection, Ocr Model\Gen Ai through computre vision\new generate image.jpg',cv2.IMREAD_GRAYSCALE)

# %%
img_gray.shape # it dont have 3 channel now
# Out:
# (300, 220)

# %%
img_gray
# Out:
# array([[ 69,  52,  48, ..., 115, 106,  90],
#        [ 41,  76,  80, ..., 157, 134, 118],
#        [ 75,  90, 101, ..., 109,  92, 100],
#        ...,
#        [ 30,  28,  24, ...,  68, 104,  74],
#        [ 31,  27,  26, ...,  85, 107,  84],
#        [ 37,  28,  29, ...,  79,  65,  57]], dtype=uint8)

# %%
img_gray.min()
# Out:
# np.uint8(7)

# %%
img_gray.max()
# Out:
# np.uint8(255)

# %%
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap = 'magma') # try with green

# %%
#plt.imshow(img_gray, cmap = 'green')
plt.imshow(img_gray, cmap = 'Accent')

# %%
plt.imshow(img)

# %%
plt.imshow(fix_img)

# %%
fix_img.shape
# Out:
# (300, 220, 3)

# %%
fix_img_1 = cv2.resize(fix_img,(600,500)) # 600 -width & 500- height

# %%
plt.imshow(fix_img_1)

# %%
fix_img.shape
# Out:
# (300, 220, 3)

# %%
w_ratio = 0.3
h_ratio = 0.3

# %%
fix_img_2 = cv2.resize(fix_img,(0,0), fix_img, w_ratio, h_ratio)

# %%
fix_img_2.shape # 50% of the fix_img shape
# Out:
# (90, 66, 3)

# %%
plt.imshow(fix_img_2)

# %%
plt.imshow(fix_img)

# %%
img3 = cv2.flip(fix_img_2,0)
plt.imshow(img3)

# %%
cv2.imwrite('new generate image.jpg',img3)
# Out:
# True
